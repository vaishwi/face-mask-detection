# %% [markdown]
# Learning rate = 0.01
# epoch 15
# Optimizer = Adam
# Model - MobileNet
# images - rgb with full range value without normalization
# three layes added at top - dense(1000), dropout, dense

# %%
import numpy as np
import cv2

import PIL.Image as Image
import PIL
import os

import matplotlib.pylab as plt

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
data_dir = pathlib.Path("./final_dataset/")
data_dir
# Out:
# PosixPath('final_dataset')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Read image files

# %%
from matplotlib import path
data_images_dict = {
    'Mask': list(data_dir.glob('**/mask/*')),
    'Improper Mask': list(data_dir.glob('**/improper_mask/*')),
    'Non Mask': list(data_dir.glob('**/no_mask/*'))
}

# %%
data_labels_dict = {
    'Mask': 0,
    'Improper Mask': 1,
    'Non Mask': 2
}

# %% [markdown]
# ## Image to CSV

# %%
X, y = [], []

for image_name, images in data_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(224,224))
        X.append(resized_img)
        y.append(data_labels_dict[image_name])

# %%
X = np.array(X)
y = np.array(y)

# %% [markdown]
# # Visualization

# %% [markdown]
# # Model training

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
IMAGE_SHAPE=(224,224)

# %%
IMAGE_SHAPE+(3,)
# Out:
# (224, 224, 3)

# %%
plt.axis('off')
plt.imshow(X[500])

# %%
pretrained_model_without_top_layer = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3), alpha=1.0, include_top=False, weights='imagenet',
    input_tensor=None, pooling="avg")

# %%
for layers in pretrained_model_without_top_layer.layers:
  layers.trainable = False

# %%
num_of_classes = 3

model = tf.keras.Sequential([
    pretrained_model_without_top_layer,
    tf.keras.layers.Dense(1000),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(num_of_classes)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 1280)             2257984
#  ional)
#
#  dense (Dense)               (None, 1000)              1281000
#
#  batch_normalization (BatchN  (None, 1000)             4000
#  ormalization)
#
#  dropout (Dropout)           (None, 1000)              0
#
#  batch_normalization_1 (Batc  (None, 1000)             4000
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 1000)              0
#
#  dense_1 (Dense)             (None, 3)                 3003
#
# =================================================================
# Total params: 3,549,987
# Trainable params: 1,288,003
# Non-trainable params: 2,261,984
# _________________________________________________________________

# %%
model.compile(
  optimizer=keras.optimizers.Adam(learning_rate=0.000001),
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])

# %%
weight_dir = "weights/50_epoch_mobilenetv2_more_layers_LR_LOW"
if not os.path.exists(weight_dir):
    os.mkdir(weight_dir)
    
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=weight_dir+'/checkpoint-{epoch:02d}.hdf5')

# %%
# history = model.fit(X_train_scaled, y_train, epochs=15,initial_epoch=11,callbacks=[checkpoint])
history = model.fit(X_train_scaled, y_train, epochs=50,callbacks=[checkpoint],validation_split=0.20,batch_size=10)
# Out:
# Epoch 1/50
# 2022-12-06 21:30:05.939908: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 573/573 [==============================] - 64s 108ms/step - loss: 1.1060 - acc: 0.5469 - val_loss: 0.6080 - val_acc: 0.7605
# Epoch 2/50
# 573/573 [==============================] - 55s 96ms/step - loss: 0.7376 - acc: 0.6964 - val_loss: 0.3939 - val_acc: 0.8527
# Epoch 3/50
# 573/573 [==============================] - 57s 99ms/step - loss: 0.5535 - acc: 0.7770 - val_loss: 0.2835 - val_acc: 0.8925
# Epoch 4/50
# 573/573 [==============================] - 62s 108ms/step - loss: 0.4618 - acc: 0.8168 - val_loss: 0.2263 - val_acc: 0.9134
# Epoch 5/50
# 573/573 [==============================] - 59s 103ms/step - loss: 0.3995 - acc: 0.8430 - val_loss: 0.1891 - val_acc: 0.9316
# Epoch 6/50
# 573/573 [==============================] - 60s 105ms/step - loss: 0.3750 - acc: 0.8552 - val_loss: 0.1632 - val_acc: 0.9434
# Epoch 7/50
# 573/573 [==============================] - 58s 102ms/step - loss: 0.3253 - acc: 0.8752 - val_loss: 0.1395 - val_acc: 0.9518
# Epoch 8/50
# 573/573 [==============================] - 57s 100ms/step - loss: 0.3050 - acc: 0.8874 - val_loss: 0.1320 - val_acc: 0.9581
# Epoch 9/50
# 573/573 [==============================] - 58s 101ms/step - loss: 0.2803 - acc: 0.8977 - val_loss: 0.1185 - val_acc: 0.9616
# Epoch 10/50
# 573/573 [==============================] - 59s 103ms/step - loss: 0.2727 - acc: 0.9031 - val_loss: 0.1094 - val_acc: 0.9651
# Epoch 11/50
# 573/573 [==============================] - 59s 104ms/step - loss: 0.2438 - acc: 0.9123 - val_loss: 0.1033 - val_acc: 0.9651
# Epoch 12/50
# 573/573 [==============================] - 60s 104ms/step - loss: 0.2338 - acc: 0.9132 - val_loss: 0.0970 - val_acc: 0.9672
# Epoch 13/50
# 573/573 [==============================] - 61s 107ms/step - loss: 0.2215 - acc: 0.9178 - val_loss: 0.0904 - val_acc: 0.9693
# Epoch 14/50
# 573/573 [==============================] - 61s 107ms/step - loss: 0.2327 - acc: 0.9195 - val_loss: 0.0846 - val_acc: 0.9707
# Epoch 15/50
# 573/573 [==============================] - 60s 106ms/step - loss: 0.2278 - acc: 0.9233 - val_loss: 0.0824 - val_acc: 0.9693
# Epoch 16/50
# 573/573 [==============================] - 60s 105ms/step - loss: 0.2058 - acc: 0.9295 - val_loss: 0.0795 - val_acc: 0.9707
# Epoch 17/50
# 573/573 [==============================] - 59s 103ms/step - loss: 0.2028 - acc: 0.9295 - val_loss: 0.0765 - val_acc: 0.9728
# Epoch 18/50
# 573/573 [==============================] - 58s 101ms/step - loss: 0.1822 - acc: 0.9363 - val_loss: 0.0737 - val_acc: 0.9763
# Epoch 19/50
# 573/573 [==============================] - 59s 103ms/step - loss: 0.2060 - acc: 0.9284 - val_loss: 0.0715 - val_acc: 0.9763
# Epoch 20/50
# 573/573 [==============================] - 59s 104ms/step - loss: 0.1875 - acc: 0.9364 - val_loss: 0.0713 - val_acc: 0.9763
# Epoch 21/50
# 573/573 [==============================] - 59s 103ms/step - loss: 0.1849 - acc: 0.9333 - val_loss: 0.0678 - val_acc: 0.9784
# Epoch 22/50
# 573/573 [==============================] - 58s 101ms/step - loss: 0.1784 - acc: 0.9396 - val_loss: 0.0679 - val_acc: 0.9784
# Epoch 23/50
# 573/573 [==============================] - 58s 101ms/step - loss: 0.1588 - acc: 0.9478 - val_loss: 0.0657 - val_acc: 0.9777
# Epoch 24/50
# 573/573 [==============================] - 273s 476ms/step - loss: 0.1865 - acc: 0.9359 - val_loss: 0.0645 - val_acc: 0.9777
# Epoch 25/50
# 573/573 [==============================] - 3470s 6s/step - loss: 0.1759 - acc: 0.9401 - val_loss: 0.0624 - val_acc: 0.9791
# Epoch 26/50
# 573/573 [==============================] - 2611s 5s/step - loss: 0.1912 - acc: 0.9316 - val_loss: 0.0620 - val_acc: 0.9770
# Epoch 27/50
# 573/573 [==============================] - 72s 126ms/step - loss: 0.1575 - acc: 0.9439 - val_loss: 0.0594 - val_acc: 0.9797
# Epoch 28/50
# 573/573 [==============================] - 59s 102ms/step - loss: 0.1571 - acc: 0.9488 - val_loss: 0.0606 - val_acc: 0.9784
# Epoch 29/50
# 573/573 [==============================] - 56s 98ms/step - loss: 0.1746 - acc: 0.9450 - val_loss: 0.0592 - val_acc: 0.9777
# Epoch 30/50
# 573/573 [==============================] - 56s 97ms/step - loss: 0.1417 - acc: 0.9539 - val_loss: 0.0567 - val_acc: 0.9804
# Epoch 31/50
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1648 - acc: 0.9431 - val_loss: 0.0558 - val_acc: 0.9811
# Epoch 32/50
# 573/573 [==============================] - 54s 95ms/step - loss: 0.1738 - acc: 0.9429 - val_loss: 0.0561 - val_acc: 0.9811
# Epoch 33/50
# 573/573 [==============================] - 55s 97ms/step - loss: 0.1432 - acc: 0.9516 - val_loss: 0.0556 - val_acc: 0.9804
# Epoch 34/50
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1386 - acc: 0.9546 - val_loss: 0.0557 - val_acc: 0.9825
# Epoch 35/50
# 573/573 [==============================] - 56s 98ms/step - loss: 0.1549 - acc: 0.9485 - val_loss: 0.0539 - val_acc: 0.9825
# Epoch 36/50
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1450 - acc: 0.9522 - val_loss: 0.0529 - val_acc: 0.9818
# Epoch 37/50
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1369 - acc: 0.9551 - val_loss: 0.0532 - val_acc: 0.9832
# Epoch 38/50
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1429 - acc: 0.9509 - val_loss: 0.0519 - val_acc: 0.9846
# Epoch 39/50
# 573/573 [==============================] - 55s 97ms/step - loss: 0.1225 - acc: 0.9586 - val_loss: 0.0523 - val_acc: 0.9839
# Epoch 40/50
# 573/573 [==============================] - 56s 97ms/step - loss: 0.1291 - acc: 0.9546 - val_loss: 0.0528 - val_acc: 0.9832
# Epoch 41/50
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1308 - acc: 0.9560 - val_loss: 0.0517 - val_acc: 0.9832
# Epoch 42/50
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1196 - acc: 0.9597 - val_loss: 0.0502 - val_acc: 0.9853
# Epoch 43/50
# 573/573 [==============================] - 54s 95ms/step - loss: 0.1399 - acc: 0.9541 - val_loss: 0.0509 - val_acc: 0.9860
# Epoch 44/50
# 573/573 [==============================] - 54s 95ms/step - loss: 0.1258 - acc: 0.9563 - val_loss: 0.0511 - val_acc: 0.9846
# Epoch 45/50
# 573/573 [==============================] - 54s 94ms/step - loss: 0.1292 - acc: 0.9579 - val_loss: 0.0504 - val_acc: 0.9860
# Epoch 46/50
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1338 - acc: 0.9565 - val_loss: 0.0487 - val_acc: 0.9860
# Epoch 47/50
# 573/573 [==============================] - 54s 93ms/step - loss: 0.1227 - acc: 0.9577 - val_loss: 0.0482 - val_acc: 0.9874
# Epoch 48/50
# 573/573 [==============================] - 54s 95ms/step - loss: 0.1254 - acc: 0.9590 - val_loss: 0.0485 - val_acc: 0.9853
# Epoch 49/50
# 573/573 [==============================] - 54s 95ms/step - loss: 0.1235 - acc: 0.9567 - val_loss: 0.0489 - val_acc: 0.9874
# Epoch 50/50
# 573/573 [==============================] - 54s 95ms/step - loss: 0.1373 - acc: 0.9522 - val_loss: 0.0488 - val_acc: 0.9853

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 56/56 [==============================] - 13s 228ms/step - loss: 0.0454 - acc: 0.9866
# [0.04535973444581032, 0.986592173576355]

# %%
fig, axs = plt.subplots(1, 2)
fig.set_size_inches(12, 5)
axs[0].plot(history.history['acc'])
axs[0].plot(history.history['val_acc'])
axs[0].set_title('Accuracy graph')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend(['train','validation'])

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Loss graph')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend(['train','validation'])

plt.show()

# %%
model.predict(X_test_scaled[0].reshape(1,224,224,3))
# Out:
# 1/1 [==============================] - 1s 545ms/step
# array([[-5.214947  , -0.43651056,  8.767827  ]], dtype=float32)

# %%
plt.imshow(X_test[0])

# %%
y_test[0]
# Out:
# 2

# %%
type(history)
# Out:
# keras.callbacks.History

# %%
import pandas as pd
h = pd.DataFrame(history.history)

# %%
h.to_csv('history_mobilenetv2_more_layer_50_epoch.csv')

# %%
history1 = model.fit(X_train_scaled, y_train, epochs=60,initial_epoch=50,callbacks=[checkpoint],validation_split=0.20,batch_size=10)
# Out:
# Epoch 51/60
# 573/573 [==============================] - 59s 102ms/step - loss: 0.1155 - acc: 0.9621 - val_loss: 0.0476 - val_acc: 0.9874
# Epoch 52/60
# 573/573 [==============================] - 52s 91ms/step - loss: 0.1267 - acc: 0.9577 - val_loss: 0.0473 - val_acc: 0.9867
# Epoch 53/60
# 573/573 [==============================] - 54s 94ms/step - loss: 0.1406 - acc: 0.9532 - val_loss: 0.0476 - val_acc: 0.9853
# Epoch 54/60
# 573/573 [==============================] - 54s 94ms/step - loss: 0.1290 - acc: 0.9579 - val_loss: 0.0484 - val_acc: 0.9867
# Epoch 55/60
# 573/573 [==============================] - 56s 97ms/step - loss: 0.1184 - acc: 0.9623 - val_loss: 0.0466 - val_acc: 0.9860
# Epoch 56/60
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1106 - acc: 0.9635 - val_loss: 0.0464 - val_acc: 0.9867
# Epoch 57/60
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1108 - acc: 0.9630 - val_loss: 0.0470 - val_acc: 0.9874
# Epoch 58/60
# 573/573 [==============================] - 55s 96ms/step - loss: 0.1127 - acc: 0.9611 - val_loss: 0.0460 - val_acc: 0.9867
# Epoch 59/60
# 573/573 [==============================] - 55s 97ms/step - loss: 0.1240 - acc: 0.9597 - val_loss: 0.0465 - val_acc: 0.9867
# Epoch 60/60
# 573/573 [==============================] - 56s 98ms/step - loss: 0.1208 - acc: 0.9570 - val_loss: 0.0471 - val_acc: 0.9860

# %%
model = keras.models.load_model("./wcheckpoint-50.hdf5")

# %%
y_pred = model.evaluate(X_test_scaled,y_test)

# %%
import sklearn

sklearn.metrics.classification_report(y_true, y_pred)

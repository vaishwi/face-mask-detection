# %% [markdown]
# Learning rate = 0.01
# epoch 15
# Optimizer = Adam
# Model - Inceptionv3
# images - rgb with normalization
# three layes added at top - dense(1000), dropout, dense

# %%
import numpy as np
import cv2

import PIL.Image as Image
import PIL
import os

import matplotlib.pylab as plt

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
data_dir = pathlib.Path("./final_dataset/")
data_dir
# Out:
# PosixPath('final_dataset')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Read image files

# %%
from matplotlib import path
data_images_dict = {
    'Mask': list(data_dir.glob('**/mask/*')),
    'Improper Mask': list(data_dir.glob('**/improper_mask/*')),
    'Non Mask': list(data_dir.glob('**/no_mask/*'))
}

# %%
data_labels_dict = {
    'Mask': 0,
    'Improper Mask': 1,
    'Non Mask': 2
}

# %% [markdown]
# ## Image to CSV

# %%
X, y = [], []

for image_name, images in data_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(224,224))
        X.append(resized_img)
        y.append(data_labels_dict[image_name])

# %%
X = np.array(X)
y = np.array(y)

# %% [markdown]
# # Visualization

# %% [markdown]
# # Model training

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
IMAGE_SHAPE=(224,224)

# %%
IMAGE_SHAPE+(3,)
# Out:
# (224, 224, 3)

# %%
plt.axis('off')
plt.imshow(X[500])

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/inception_v3/InceptionV3
pretrained_model_without_top_layer = tf.keras.applications.inception_v3.InceptionV3(
    input_shape=(224, 224, 3), include_top=False, weights='imagenet',
    input_tensor=None, pooling="avg")

# %%
for layers in pretrained_model_without_top_layer.layers:
  layers.trainable = False

# %%
num_of_classes = 3

model = tf.keras.Sequential([
    pretrained_model_without_top_layer,
    tf.keras.layers.Dense(1000),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(num_of_classes)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  dense (Dense)               (None, 1000)              2049000
#
#  batch_normalization_94 (Bat  (None, 1000)             4000
#  chNormalization)
#
#  dropout (Dropout)           (None, 1000)              0
#
#  batch_normalization_95 (Bat  (None, 1000)             4000
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1000)              0
#
#  dense_1 (Dense)             (None, 3)                 3003
#
# =================================================================
# Total params: 23,862,787
# Trainable params: 2,056,003
# Non-trainable params: 21,806,784
# _________________________________________________________________

# %%
model.compile(
  optimizer=keras.optimizers.Adam(learning_rate=0.001),
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])

# %%
weight_dir = "weights/50_epoch_inceptionv3"
if not os.path.exists(weight_dir):
    os.mkdir(weight_dir)
    
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=weight_dir+'/checkpoint-{epoch:02d}.hdf5')

# %%
# history = model.fit(X_train_scaled, y_train, epochs=15,initial_epoch=11,callbacks=[checkpoint])
history = model.fit(X_train_scaled, y_train, epochs=50,callbacks=[checkpoint],validation_split=0.20,batch_size=10)
# Out:
# 2022-12-07 09:11:19.347266: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/50
# 573/573 [==============================] - 177s 299ms/step - loss: 0.2948 - acc: 0.9300 - val_loss: 0.2209 - val_acc: 0.9302
# Epoch 2/50
# 573/573 [==============================] - 184s 321ms/step - loss: 0.1373 - acc: 0.9534 - val_loss: 0.0991 - val_acc: 0.9637
# Epoch 3/50
# 573/573 [==============================] - 189s 330ms/step - loss: 0.1132 - acc: 0.9632 - val_loss: 0.0684 - val_acc: 0.9777
# Epoch 4/50
# 573/573 [==============================] - 195s 341ms/step - loss: 0.1055 - acc: 0.9656 - val_loss: 0.1256 - val_acc: 0.9644
# Epoch 5/50
# 573/573 [==============================] - 193s 336ms/step - loss: 0.1071 - acc: 0.9632 - val_loss: 0.1287 - val_acc: 0.9644
# Epoch 6/50
# 573/573 [==============================] - 207s 362ms/step - loss: 0.1009 - acc: 0.9675 - val_loss: 0.0767 - val_acc: 0.9797
# Epoch 7/50
# 573/573 [==============================] - 243s 424ms/step - loss: 0.0943 - acc: 0.9661 - val_loss: 0.0761 - val_acc: 0.9825
# Epoch 8/50
# 573/573 [==============================] - 225s 393ms/step - loss: 0.0911 - acc: 0.9708 - val_loss: 0.1321 - val_acc: 0.9637
# Epoch 9/50
# 573/573 [==============================] - 227s 397ms/step - loss: 0.0933 - acc: 0.9700 - val_loss: 0.0949 - val_acc: 0.9770
# Epoch 10/50
# 573/573 [==============================] - 227s 396ms/step - loss: 0.0830 - acc: 0.9740 - val_loss: 0.0676 - val_acc: 0.9777
# Epoch 11/50
# 573/573 [==============================] - 231s 403ms/step - loss: 0.0860 - acc: 0.9712 - val_loss: 0.0883 - val_acc: 0.9791
# Epoch 12/50
# 573/573 [==============================] - 218s 381ms/step - loss: 0.0838 - acc: 0.9719 - val_loss: 0.0789 - val_acc: 0.9811
# Epoch 13/50
# 573/573 [==============================] - 221s 385ms/step - loss: 0.0620 - acc: 0.9770 - val_loss: 0.0918 - val_acc: 0.9707
# Epoch 14/50
# 573/573 [==============================] - 214s 374ms/step - loss: 0.0665 - acc: 0.9785 - val_loss: 0.0792 - val_acc: 0.9804
# Epoch 15/50
# 573/573 [==============================] - 208s 363ms/step - loss: 0.0692 - acc: 0.9797 - val_loss: 0.0679 - val_acc: 0.9818
# Epoch 16/50
# 573/573 [==============================] - 212s 371ms/step - loss: 0.0757 - acc: 0.9780 - val_loss: 0.0887 - val_acc: 0.9784
# Epoch 17/50
# 573/573 [==============================] - 199s 347ms/step - loss: 0.0730 - acc: 0.9775 - val_loss: 0.0873 - val_acc: 0.9742
# Epoch 18/50
# 573/573 [==============================] - 196s 341ms/step - loss: 0.0673 - acc: 0.9787 - val_loss: 0.0702 - val_acc: 0.9811
# Epoch 19/50
# 573/573 [==============================] - 200s 349ms/step - loss: 0.0610 - acc: 0.9810 - val_loss: 0.0850 - val_acc: 0.9784
# Epoch 20/50
# 573/573 [==============================] - 202s 353ms/step - loss: 0.0624 - acc: 0.9787 - val_loss: 0.0762 - val_acc: 0.9818
# Epoch 21/50
# 573/573 [==============================] - 206s 359ms/step - loss: 0.0635 - acc: 0.9797 - val_loss: 0.1260 - val_acc: 0.9700
# Epoch 22/50
# 573/573 [==============================] - 206s 360ms/step - loss: 0.0492 - acc: 0.9839 - val_loss: 0.0843 - val_acc: 0.9749
# Epoch 23/50
# 573/573 [==============================] - 206s 359ms/step - loss: 0.0792 - acc: 0.9736 - val_loss: 0.0916 - val_acc: 0.9791
# Epoch 24/50
# 573/573 [==============================] - 1455s 3s/step - loss: 0.0503 - acc: 0.9822 - val_loss: 0.1001 - val_acc: 0.9763
# Epoch 25/50
# 573/573 [==============================] - 164s 286ms/step - loss: 0.0648 - acc: 0.9811 - val_loss: 0.0637 - val_acc: 0.9832
# Epoch 26/50
# 573/573 [==============================] - 186s 325ms/step - loss: 0.0650 - acc: 0.9792 - val_loss: 0.0806 - val_acc: 0.9839
# Epoch 27/50
# 573/573 [==============================] - 190s 332ms/step - loss: 0.0469 - acc: 0.9834 - val_loss: 0.0873 - val_acc: 0.9804
# Epoch 28/50
# 573/573 [==============================] - 191s 333ms/step - loss: 0.0542 - acc: 0.9841 - val_loss: 0.0805 - val_acc: 0.9811
# Epoch 29/50
# 573/573 [==============================] - 194s 338ms/step - loss: 0.0640 - acc: 0.9799 - val_loss: 0.1094 - val_acc: 0.9770
# Epoch 30/50
# 573/573 [==============================] - 192s 336ms/step - loss: 0.0572 - acc: 0.9818 - val_loss: 0.1469 - val_acc: 0.9693
# Epoch 31/50
# 573/573 [==============================] - 205s 357ms/step - loss: 0.0645 - acc: 0.9831 - val_loss: 0.0921 - val_acc: 0.9791
# Epoch 32/50
# 573/573 [==============================] - 202s 353ms/step - loss: 0.0569 - acc: 0.9810 - val_loss: 0.0854 - val_acc: 0.9797
# Epoch 33/50
# 573/573 [==============================] - 188s 328ms/step - loss: 0.0448 - acc: 0.9871 - val_loss: 0.0896 - val_acc: 0.9763
# Epoch 34/50
# 573/573 [==============================] - 206s 359ms/step - loss: 0.0460 - acc: 0.9852 - val_loss: 0.0811 - val_acc: 0.9818
# Epoch 35/50
# 573/573 [==============================] - 219s 383ms/step - loss: 0.0587 - acc: 0.9813 - val_loss: 0.1304 - val_acc: 0.9721
# Epoch 36/50
# 573/573 [==============================] - 245s 427ms/step - loss: 0.0564 - acc: 0.9825 - val_loss: 0.1600 - val_acc: 0.9574
# Epoch 37/50
# 573/573 [==============================] - 281s 491ms/step - loss: 0.0478 - acc: 0.9848 - val_loss: 0.0746 - val_acc: 0.9853
# Epoch 38/50
# 573/573 [==============================] - 267s 466ms/step - loss: 0.0322 - acc: 0.9869 - val_loss: 0.1508 - val_acc: 0.9693
# Epoch 39/50
# 573/573 [==============================] - 270s 471ms/step - loss: 0.0463 - acc: 0.9862 - val_loss: 0.0847 - val_acc: 0.9825
# Epoch 40/50
# 573/573 [==============================] - 278s 485ms/step - loss: 0.0448 - acc: 0.9853 - val_loss: 0.0846 - val_acc: 0.9846
# Epoch 41/50
# 573/573 [==============================] - 282s 492ms/step - loss: 0.0587 - acc: 0.9810 - val_loss: 0.0696 - val_acc: 0.9846
# Epoch 42/50
# 573/573 [==============================] - 292s 509ms/step - loss: 0.0321 - acc: 0.9900 - val_loss: 0.0865 - val_acc: 0.9777
# Epoch 43/50
# 573/573 [==============================] - 251s 439ms/step - loss: 0.0332 - acc: 0.9880 - val_loss: 0.0741 - val_acc: 0.9825
# Epoch 44/50
# 573/573 [==============================] - 284s 497ms/step - loss: 0.0460 - acc: 0.9866 - val_loss: 0.0794 - val_acc: 0.9818
# Epoch 45/50
# 573/573 [==============================] - 287s 502ms/step - loss: 0.0601 - acc: 0.9799 - val_loss: 0.0733 - val_acc: 0.9825
# Epoch 46/50
# 573/573 [==============================] - 222s 388ms/step - loss: 0.0492 - acc: 0.9864 - val_loss: 0.0734 - val_acc: 0.9832
# Epoch 47/50
# 573/573 [==============================] - 230s 401ms/step - loss: 0.0562 - acc: 0.9839 - val_loss: 0.0689 - val_acc: 0.9832
# Epoch 48/50
# 573/573 [==============================] - 224s 391ms/step - loss: 0.0334 - acc: 0.9890 - val_loss: 0.0672 - val_acc: 0.9867
# Epoch 49/50
# 573/573 [==============================] - 218s 381ms/step - loss: 0.0449 - acc: 0.9848 - val_loss: 0.0876 - val_acc: 0.9797
# Epoch 50/50
# 573/573 [==============================] - 223s 390ms/step - loss: 0.0386 - acc: 0.9866 - val_loss: 0.0790 - val_acc: 0.9791

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 56/56 [==============================] - 54s 965ms/step - loss: 0.0734 - acc: 0.9821
# [0.07336793839931488, 0.9821228981018066]

# %%
fig, axs = plt.subplots(1, 2)
fig.set_size_inches(12, 5)
axs[0].plot(history.history['acc'])
axs[0].plot(history.history['val_acc'])
axs[0].set_title('Accuracy graph')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend(['train','validation'])

axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('Loss graph')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend(['train','validation'])

plt.show()

# %%
# mask_model =  tf.keras.models.load_model("weights/2805_1/checkpoint-15.hdf5")

# %%
model.predict(X_test_scaled[0].reshape(1,224,224,3))
# Out:
# 1/1 [==============================] - 1s 797ms/step
# array([[ -3.4782634, -14.267399 ,  13.3852215]], dtype=float32)

# %%
plt.imshow(X_test[0])

# %%
y_test[0]
# Out:
# 2

# %%
import pandas as pd
h = pd.DataFrame(history.history)
h.to_csv("Inception_50_epoch.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 import pandas as pd
# ----> 2 h = pd.DataFram(history.history)
#       3 h.to_csv("Inception_50_epoch.csv")
#
# File ~/Documents/MLBD/venv/lib/python3.9/site-packages/pandas/__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'DataFram'
